# %% [markdown]
# ### Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sem-4/Healthcare/Life_Expectancy_Data  (dataset-2).csv')

# %% [markdown]
# ### **Dataset Overview:**

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0              263
# 1     Afghanistan  2014  Developing              59.9              271
# 2     Afghanistan  2013  Developing              59.9              268
# 3     Afghanistan  2012  Developing              59.5              272
# 4     Afghanistan  2011  Developing              59.2              275
# ...           ...   ...         ...               ...              ...
# 1644     Zimbabwe  2004  Developing              44.3              723
# 1645     Zimbabwe  2003  Developing              44.5              715
# 1646     Zimbabwe  2002  Developing              44.8               73
# 1647     Zimbabwe  2001  Developing              45.3              686
# 1648     Zimbabwe  2000  Developing              46.0              665
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.shape
# Out:
# (1649, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %% [markdown]
# ### Checking NaN Values in Data

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ### Disply DataTypes

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                      int64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                          int64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                                int64
# Total expenditure                  float64
# Diphtheria                           int64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %% [markdown]
# ### **Descriptive Statistics:**

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  1649.000000       1649.000000      1649.000000    1649.000000
# mean   2007.840509         69.302304       168.215282      32.553062
# std       4.087711          8.796834       125.310417     120.847190
# min    2000.000000         44.000000         1.000000       0.000000
# 25%    2005.000000         64.400000        77.000000       1.000000
# 50%    2008.000000         71.700000       148.000000       3.000000
# 75%    2011.000000         75.000000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('-', '_')

df.columns = df.columns.str.strip('_')

df.rename(columns={'_thinness_1_19_years': 'thinness_1_19_years',
                   '_thinness_5_9_years': 'thinness_5_9_years'}, inplace=True)

print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles', 'BMI', 'under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness__1_19_years',
#        'thinness_5_9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ### *Correlation Analysis:*
#
# Interpretation of the correlation matrix:
#
#
#
# *   A value close to 1 indicates a strong positive correlation.
# *   A value close to -1 indicates a strong negative correlation.
# *   A value close to 0 indicates a weak or no correlation.

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Box Plot for Outlier Detection:

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Creating box plots for each numerical column
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.boxplot(df[column])
    plt.title(f'Box plot for {column}')
    plt.show()

# %% [markdown]
# ### Removing Outliers :

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Removing outliers using IQR method with adjusted multiplier
for column in numerical_columns:
    # Calculate IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define the upper and lower bounds with an adjusted multiplier (e.g., 2.5 instead of 1.5)
    lower_bound = Q1 - 2.5 * IQR
    upper_bound = Q3 + 2.5 * IQR

    # Remove outliers
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Creating box plots for each numerical column after removing outliers
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.boxplot(df[column])
    plt.title(f'Box plot for {column} (Some Outliers Removed)')
    plt.show()

# %%
df = df.drop(columns=['HIV/AIDS'])

# %% [markdown]
# ### Univariate Analysis for Categorical Variables:

# %%
# Calculate count of each category in the 'Status' column
status_counts = df['Status'].value_counts()

# Define custom colors
custom_colors = ['#ff9999', '#66b3ff']

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140, colors=custom_colors, wedgeprops={'edgecolor': 'black'})
plt.title('Percentage of Status')

# Add circle in the middle to make it a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ### Univariate Analysis for Numeric Variables:

# %%
columns_for_histogram = ['Life_expectancy', 'Adult_Mortality', 'BMI', 'Total_expenditure', 'GDP', 'Income_composition_of_resources']
colors = ['skyblue', 'lightgreen', 'salmon', 'orange', 'purple', 'yellow']

for column, color in zip(columns_for_histogram, colors):
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=20, color=color, edgecolor='black')

    trend_value = df[column].median()
    plt.axvline(trend_value, color='red', linestyle='dashed', linewidth=1, label=f'Median: {trend_value:.2f}')

    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Bivariate Analysis for Categorical-Categorical Relationships:

# %%
# Count the number of countries in each development status
status_counts = df['Status'].value_counts()

# Create a horizontal bar plot
plt.figure(figsize=(10, 8))
status_counts.plot(kind='barh', color=['skyblue', 'orange'])
plt.title('Number of Countries by Development Status')
plt.xlabel('Number of Countries')
plt.ylabel('Development Status')
plt.gca().invert_yaxis()  # Invert y-axis to have 'Developed' at the top
plt.show()

# %% [markdown]
# ### Bivariate Analysis for Numeric-Numeric Relationships:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculating Avg Life Expectancy Per Year
avg_life = [df[df['Year'] == year]['Life_expectancy'].mean() for year in df['Year'].unique()]

# Customizing color palette
sns.set_palette("husl")

fig = plt.figure(figsize=(10,5))
sns.lineplot(x=df['Year'].unique(), y=avg_life, marker='o', linewidth=2)  # Adjust linewidth as needed
plt.ylabel('Avg Life Expectancy', fontsize=12)  # Adjust font size as needed
plt.xlabel('Years', fontsize=12)  # Adjust font size as needed
plt.title('Trend for Life Expectancy wrt Year', fontsize=14)  # Adjust font size as needed
plt.grid(True)  # Add grid for better visualization
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

plt.figure(figsize=(15,5))

# %% [markdown]
# ### Bivariate Analysis for Numeric-Categorical Relationships:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have df, X, and avg_life_country defined

# Create a custom color palette
custom_palette = sns.color_palette("coolwarm", len(X[:5]))  # You can choose any other seaborn color palette

data = pd.DataFrame({'Country': X[:5], 'Life_expectancy': avg_life_country[:5]})

fig = plt.figure(figsize=(20, 8))
sns.barplot(data=data, x='Country', y='Life_expectancy', palette=custom_palette)
plt.title('Life Expectancy by Country', fontsize=16)  # Set title and adjust font size
plt.xlabel('Country', fontsize=14)  # Set x-axis label and adjust font size
plt.ylabel('Life Expectancy', fontsize=14)  # Set y-axis label and adjust font size
plt.xticks(fontsize=12, rotation=45)  # Adjust x-axis tick label font size and rotation for better readability
plt.yticks(fontsize=12)  # Adjust y-axis tick label font size
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for y-axis
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# <ipython-input-63-2817513f9876>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Country', y='Life_expectancy', palette=custom_palette)

# %% [markdown]
# ### Bivariate Analysis for Numeric-Categorical Relationships:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have df, X, and avg_life_country defined

# Customizing color palette
custom_palette = sns.color_palette("husl", len(X))

fig = plt.figure(figsize=(20, 8))
sns.barplot(data=data, x='Country', y='Life_expectancy', palette=custom_palette)

# Add shine effect by adjusting alpha (transparency) and linewidth
for patch in plt.gca().patches:
    patch.set_alpha(0.7)  # Adjust alpha (transparency) as needed
    patch.set_edgecolor('black')  # Add black edges for better visibility
    patch.set_linewidth(1.5)  # Adjust linewidth as needed

plt.title('Life Expectancy by Country', fontsize=16)  # Adjust title font size as needed
plt.xlabel('Country', fontsize=14)  # Adjust x-axis label font size as needed
plt.ylabel('Life Expectancy', fontsize=14)  # Adjust y-axis label font size as needed
plt.xticks(fontsize=12, rotation=45, ha='right')  # Adjust x-axis tick font size and rotation angle as needed
plt.yticks(fontsize=12)  # Adjust y-axis tick font size as needed
plt.grid(axis='y', linestyle='--', alpha=0.5)  # Add horizontal gridlines for better visualization

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# <ipython-input-67-c97e4dd0ae0d>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Country', y='Life_expectancy', palette=custom_palette)
# <ipython-input-67-c97e4dd0ae0d>:10: UserWarning: The palette list has more values (86) than needed (5), which may not be intended.
#   sns.barplot(data=data, x='Country', y='Life_expectancy', palette=custom_palette)

# %% [markdown]
# ### Multivariate

# %%
fig = plt.figure(figsize=(10,5))
sns.lineplot(data=df,x='Year',y='Adult_Mortality',label = 'Adult Mortality')
sns.lineplot(data=df,x='Year',y='infant_deaths',label = 'Infant Deaths')
sns.lineplot(data=df,x='Year',y='Life_expectancy',label = 'Life expectancy ')
plt.legend()

# %% [markdown]
# ### Below part is not necessrily required , i just done it for checking ML

# %% [markdown]
# ### Income, GdP, Population, adust vs death vs life expectancy

# %%
# first i neet to split data to train and tes

# import need function
from sklearn.model_selection import train_test_split

# spliting data to train and test
train, test =  train_test_split(df, test_size = 0.2, random_state = 42)

# %%
print(f"Shape of train data is : {train.shape}")
print("-" * 30)
print(f"Shape of test data is : {test.shape}")
# Out:
# Shape of train data is : (470, 21)
# ------------------------------
# Shape of test data is : (118, 21)

# %%
train["Country"].nunique()
# Out:
# 85

# %%
def count_plot(y_axis, top):
    top_countries = df[y_axis].value_counts().nlargest(top).index
    df_top = df[df[y_axis].isin(top_countries)]
    plt.barh(df_top[y_axis], df_top['Life_expectancy'])
    plt.xlabel('Life Expectancy')
    plt.ylabel(y_axis)
    plt.title(f'Top {top} Countries by {y_axis} and their Life Expectancy')
    plt.show()

plt.figure(figsize=(15, 6))
count_plot(y_axis="Country", top=10)

# %%
train["Year"].unique()
# Out:
# array([2002, 2003, 2005, 2007, 2008, 2011, 2014, 2009, 2013, 2010, 2001,
#        2015, 2006, 2000, 2012, 2004])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have imported your data and stored it in a DataFrame called 'data'

plt.figure(figsize=(15, 6))
sns.countplot(x="Year", data=df)
plt.show()

# %%
train["Status"].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
import matplotlib.pyplot as plt

# Assuming 'Status' column exists in your DataFrame df
status_counts = df['Status'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
train.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life_expectancy                    0
# Adult_Mortality                    0
# infant_deaths                      0
# Alcohol                            0
# percentage_expenditure             0
# Hepatitis_B                        0
# Measles                            0
# BMI                                0
# under_five_deaths                  0
# Polio                              0
# Total_expenditure                  0
# Diphtheria                         0
# GDP                                0
# Population                         0
# thinness__1_19_years               0
# thinness_5_9_years                 0
# Income_composition_of_resources    0
# Schooling                          0
# dtype: int64

# %%
fig = plt.figure(figsize=(10,5))
sns.lineplot(data=df,x='Year',y='Adult_Mortality',label = 'Adult Mortality')
sns.lineplot(data=df,x='Year',y='infant_deaths',label = 'Infant Deaths')
sns.lineplot(data=df,x='Year',y='Life_expectancy',label = 'Life expectancy ')
plt.legend()
